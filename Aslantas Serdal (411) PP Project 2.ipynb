# %% [markdown]
# # PERFORMANCE COMPARISON OF BAYESIAN NEURAL NETWORK AND 'CLASSICAL' NEURAL NETWORK

# %% [markdown]
# # Sanity Check

# %%
# import the necessary libraries
import numpy as np
from sklearn import datasets
import torch
import torch.nn as nn
import torch.optim as optim
import torchbnn as bnn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# we generate a random numpy array with two features 
# and 100 data points and we create a label with tanh function. 
X = np.random.randn(100, 2)
Y = np.tanh(X[:, 0] + X[:, 1])
Y = 1. / (1. + np.exp(-(Y + Y)))
Y = Y > 0.5

# %%
# we convert the numpy array to tensor to train our neural network.
x, y = torch.from_numpy(X).float(), torch.from_numpy(Y).long()
x.shape, y.shape
# Out:
# (torch.Size([100, 2]), torch.Size([100]))

# %% [markdown]
# We create a bayesian neural network with three layers. Our prior is normal distribution, mu=0, sigma=1

# %%
model = nn.Sequential(
    bnn.BayesLinear(prior_mu=0, prior_sigma=1, in_features=2, out_features=100),
    nn.ReLU(),
    bnn.BayesLinear(prior_mu=0, prior_sigma=1, in_features=100, out_features=100),
    nn.ReLU(),
    bnn.BayesLinear(prior_mu=0, prior_sigma=1, in_features=100, out_features=2),
)

# %%
ce_loss = nn.CrossEntropyLoss()
kl_loss = bnn.BKLLoss(reduction='mean', last_layer_only=False)
kl_weight = 0.01
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %% [markdown]
# Here we train the BNN model and calculate the crossentropy loss and The Kullback-Leibler divergence loss. Later we make a prediction of the label and calculate the accuracy of the model. It perfectly classifies the datas eventually.

# %%
for step in range(1000):
    pre = model(x)
    ce = ce_loss(pre, y)
    kl = kl_loss(model)
    cost = ce + kl_weight*kl
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
_, predicted = torch.max(pre.data, 1)
total = y.size(0)
correct = (predicted == y).sum()
print('- Accuracy: %f %%' % (100 * float(correct) / total))
print('- CE : %2.2f, KL : %2.2f' % (ce.item(), kl.item()))
# Out:
# - Accuracy: 100.000000 %
# - CE : 0.00, KL : 0.18

# %%
# Data visualization of the two datasets.
def draw_plot(predicted) :
    fig = plt.figure(figsize = (18, 6))

    ax1 = fig.add_subplot(1, 2, 1)
    ax2 = fig.add_subplot(1, 2, 2)

    z1_plot = ax1.scatter(X[:, 0], X[:, 1], c = Y)
    z2_plot = ax2.scatter(X[:, 0], X[:, 1], c = predicted)

    plt.colorbar(z1_plot,ax=ax1)
    plt.colorbar(z2_plot,ax=ax2)

    ax1.set_title("Real Dataset")
    ax2.set_title("Predicted Dataset")

    plt.show()

# %%
pre = model(x)
_, predicted = torch.max(pre.data, 1)
draw_plot(predicted)

# %% [markdown]
# # Bayesian Neural Network  on the toy dataset, Make_moons

# %%
X ,y = datasets.make_moons(noise=0.2, random_state=0, n_samples=1000)

# %%
# We first convert the numpy array into a tensor
x,y  = torch.from_numpy(X).float(),torch.from_numpy(y).long()
x.shape, y.shape
# Out:
# (torch.Size([1000, 2]), torch.Size([1000]))

# %%
for step in range(3000):
    pre = model(x)
    ce = ce_loss(pre,y)
    kl = kl_loss(model)
    cost = ce + kl_weight*kl
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
_, predicted = torch.max(pre.data, 1)
total = y.size(0)
correct = (predicted == y).sum()
print('- Accuracy: %f %%' % (100 * float(correct) / total))
print('- CE : %2.2f, KL : %2.2f' % (ce.item(), kl.item()))
# Out:
# - Accuracy: 96.800000 %
# - CE : 0.08, KL : 0.26

# %%
def draw_plot(predicted) :
    fig = plt.figure(figsize = (16, 5))

    ax1 = fig.add_subplot(1, 2, 1)
    ax2 = fig.add_subplot(1, 2, 2)

    z1_plot = ax1.scatter(X[:, 0], X[:, 1], c = y)
    z2_plot = ax2.scatter(X[:, 0], X[:, 1], c = predicted)

    plt.colorbar(z1_plot,ax=ax1)
    plt.colorbar(z2_plot,ax=ax2)

    ax1.set_title("REAL")
    ax2.set_title("PREDICT")

    plt.show()

# %%
pre = model(x)
_, predicted = torch.max(pre.data, 1)
draw_plot(predicted)

# %% [markdown]
# # Classical neural network

# %%
# We define the keras model
model = Sequential()
model.add(Dense(12, input_dim=2, activation='relu'))
model.add(Dense(2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
X ,y = datasets.make_moons(noise=0.2, random_state=0, n_samples=1000)

# %%
# fit the keras model on the dataset

model.fit(X, y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.7583 - accuracy: 0.4540
# Epoch 2/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.6416 - accuracy: 0.5720
# Epoch 3/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5851 - accuracy: 0.6700
# Epoch 4/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5477 - accuracy: 0.7060
# Epoch 5/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5220 - accuracy: 0.7550
# Epoch 6/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.5012 - accuracy: 0.7670
# Epoch 7/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4803 - accuracy: 0.7950
# Epoch 8/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4598 - accuracy: 0.8050
# Epoch 9/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4406 - accuracy: 0.8230
# Epoch 10/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4222 - accuracy: 0.8320
# Epoch 11/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.4033 - accuracy: 0.8530
# Epoch 12/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3881 - accuracy: 0.8590
# Epoch 13/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3756 - accuracy: 0.8650
# Epoch 14/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3642 - accuracy: 0.8710
# Epoch 15/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3537 - accuracy: 0.8730
# Epoch 16/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3446 - accuracy: 0.8790
# Epoch 17/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3365 - accuracy: 0.8850
# Epoch 18/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3281 - accuracy: 0.8840
# Epoch 19/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3210 - accuracy: 0.8860
# Epoch 20/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3144 - accuracy: 0.8900
# Epoch 21/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3078 - accuracy: 0.8950
# Epoch 22/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.3027 - accuracy: 0.8970
# Epoch 23/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2964 - accuracy: 0.8980
# Epoch 24/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2918 - accuracy: 0.9040
# Epoch 25/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2863 - accuracy: 0.9050
# Epoch 26/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2820 - accuracy: 0.9040
# Epoch 27/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2772 - accuracy: 0.9040
# Epoch 28/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2734 - accuracy: 0.9050
# Epoch 29/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2696 - accuracy: 0.9080
# Epoch 30/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2658 - accuracy: 0.9090
# Epoch 31/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2615 - accuracy: 0.9100
# Epoch 32/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2584 - accuracy: 0.9110
# Epoch 33/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2542 - accuracy: 0.9120
# Epoch 34/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2500 - accuracy: 0.9120
# Epoch 35/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2466 - accuracy: 0.9150
# Epoch 36/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2427 - accuracy: 0.9160
# Epoch 37/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2398 - accuracy: 0.9180
# Epoch 38/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2358 - accuracy: 0.9170
# Epoch 39/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2325 - accuracy: 0.9190
# Epoch 40/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2277 - accuracy: 0.9210
# Epoch 41/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.2236 - accuracy: 0.9220
# Epoch 42/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2198 - accuracy: 0.9230
# Epoch 43/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2153 - accuracy: 0.9270
# Epoch 44/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2118 - accuracy: 0.9310
# Epoch 45/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2077 - accuracy: 0.9300
# Epoch 46/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.2040 - accuracy: 0.9340
# Epoch 47/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1997 - accuracy: 0.9340
# Epoch 48/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1950 - accuracy: 0.9370
# Epoch 49/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1923 - accuracy: 0.9340
# Epoch 50/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1874 - accuracy: 0.9400
# Epoch 51/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1841 - accuracy: 0.9400
# Epoch 52/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1795 - accuracy: 0.9400
# Epoch 53/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1764 - accuracy: 0.9410
# Epoch 54/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1726 - accuracy: 0.9420
# Epoch 55/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1704 - accuracy: 0.9450
# Epoch 56/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1666 - accuracy: 0.9460
# Epoch 57/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1634 - accuracy: 0.9470
# Epoch 58/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1591 - accuracy: 0.9500
# Epoch 59/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1569 - accuracy: 0.9470
# Epoch 60/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1549 - accuracy: 0.9520
# Epoch 61/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1514 - accuracy: 0.9520
# Epoch 62/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1487 - accuracy: 0.9530
# Epoch 63/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1460 - accuracy: 0.9540
# Epoch 64/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1439 - accuracy: 0.9570
# Epoch 65/150
# 100/100 [==============================] - 0s 4ms/step - loss: 0.1422 - accuracy: 0.9570
# Epoch 66/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1408 - accuracy: 0.9550
# Epoch 67/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1378 - accuracy: 0.9580
# Epoch 68/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1358 - accuracy: 0.9580
# Epoch 69/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1345 - accuracy: 0.9570
# Epoch 70/150
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1329 - accuracy: 0.9560
# Epoch 71/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1312 - accuracy: 0.9590
# Epoch 72/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1292 - accuracy: 0.9590
# Epoch 73/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1291 - accuracy: 0.9580
# Epoch 74/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1270 - accuracy: 0.9590
# Epoch 75/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1260 - accuracy: 0.9590
# Epoch 76/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1241 - accuracy: 0.9600
# Epoch 77/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1230 - accuracy: 0.9600
# Epoch 78/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1226 - accuracy: 0.9620
# Epoch 79/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1216 - accuracy: 0.9590
# Epoch 80/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1200 - accuracy: 0.9590
# Epoch 81/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1181 - accuracy: 0.9610
# Epoch 82/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1175 - accuracy: 0.9590
# Epoch 83/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1164 - accuracy: 0.9590
# Epoch 84/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1162 - accuracy: 0.9600
# Epoch 85/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1151 - accuracy: 0.9610
# Epoch 86/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1145 - accuracy: 0.9590
# Epoch 87/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1134 - accuracy: 0.9610
# Epoch 88/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1139 - accuracy: 0.9610
# Epoch 89/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1126 - accuracy: 0.9620
# Epoch 90/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1118 - accuracy: 0.9620
# Epoch 91/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1111 - accuracy: 0.9610
# Epoch 92/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1104 - accuracy: 0.9620
# Epoch 93/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1102 - accuracy: 0.9650
# Epoch 94/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1094 - accuracy: 0.9630
# Epoch 95/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1093 - accuracy: 0.9600
# Epoch 96/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1087 - accuracy: 0.9610
# Epoch 97/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1080 - accuracy: 0.9630
# Epoch 98/150
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1067 - accuracy: 0.9590
# Epoch 99/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1072 - accuracy: 0.9600
# Epoch 100/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1064 - accuracy: 0.9620
# Epoch 101/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1059 - accuracy: 0.9620
# Epoch 102/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1053 - accuracy: 0.9620
# Epoch 103/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1056 - accuracy: 0.9610
# Epoch 104/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1050 - accuracy: 0.9630
# Epoch 105/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1046 - accuracy: 0.9630
# Epoch 106/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1038 - accuracy: 0.9630
# Epoch 107/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1034 - accuracy: 0.9640
# Epoch 108/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1041 - accuracy: 0.9610
# Epoch 109/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.9630
# Epoch 110/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1031 - accuracy: 0.9600
# Epoch 111/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1022 - accuracy: 0.9610
# Epoch 112/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.9640
# Epoch 113/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1020 - accuracy: 0.9620
# Epoch 114/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1021 - accuracy: 0.9620
# Epoch 115/150
# 100/100 [==============================] - 0s 3ms/step - loss: 0.1009 - accuracy: 0.9620
# Epoch 116/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1010 - accuracy: 0.9630
# Epoch 117/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1007 - accuracy: 0.9660
# Epoch 118/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1011 - accuracy: 0.9620
# Epoch 119/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.1000 - accuracy: 0.9620
# Epoch 120/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1006 - accuracy: 0.9610
# Epoch 121/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0997 - accuracy: 0.9650
# Epoch 122/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1009 - accuracy: 0.9670
# Epoch 123/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0994 - accuracy: 0.9650
# Epoch 124/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.1000 - accuracy: 0.9620
# Epoch 125/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0991 - accuracy: 0.9620
# Epoch 126/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0993 - accuracy: 0.9650
# Epoch 127/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0986 - accuracy: 0.9650
# Epoch 128/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0980 - accuracy: 0.9640
# Epoch 129/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0989 - accuracy: 0.9660
# Epoch 130/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0980 - accuracy: 0.9640
# Epoch 131/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0991 - accuracy: 0.9650
# Epoch 132/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0980 - accuracy: 0.9640
# Epoch 133/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0977 - accuracy: 0.9640
# Epoch 134/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0981 - accuracy: 0.9620
# Epoch 135/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0975 - accuracy: 0.9660
# Epoch 136/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0974 - accuracy: 0.9670
# Epoch 137/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0981 - accuracy: 0.9630
# Epoch 138/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0977 - accuracy: 0.9630
# Epoch 139/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0969 - accuracy: 0.9640
# Epoch 140/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0967 - accuracy: 0.9650
# Epoch 141/150
# 100/100 [==============================] - 0s 1ms/step - loss: 0.0972 - accuracy: 0.9640
# Epoch 142/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0961 - accuracy: 0.9640
# Epoch 143/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0972 - accuracy: 0.9630
# Epoch 144/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0974 - accuracy: 0.9670
# Epoch 145/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0962 - accuracy: 0.9650
# Epoch 146/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0966 - accuracy: 0.9650
# Epoch 147/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0959 - accuracy: 0.9650
# Epoch 148/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0970 - accuracy: 0.9640
# Epoch 149/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0961 - accuracy: 0.9640
# Epoch 150/150
# 100/100 [==============================] - 0s 2ms/step - loss: 0.0955 - accuracy: 0.9650

# %%
# We evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0942 - accuracy: 0.9670
# Accuracy: 96.70

# %% [markdown]
# # Multinomial Classification

# %%
# We create an artificial dataset with 6 features and calculate its label with tanh function
X = np.random.randn(100, 6)
Y = np.tanh(X[:, 0] + X[:, 1]+ X[:, 2]+ X[:, 3]+ X[:, 4]+ X[:, 5])
Y = 1. / (1. + np.exp(-(Y + Y)))
Y = Y > 0.5

# %%
x, y = torch.from_numpy(X).float(), torch.from_numpy(Y).long()
x.shape, y.shape
# Out:
# (torch.Size([100, 6]), torch.Size([100]))

# %%
model = nn.Sequential(
    bnn.BayesLinear(prior_mu=0, prior_sigma=0.1, in_features=6, out_features=100),
    nn.ReLU(),
    bnn.BayesLinear(prior_mu=0, prior_sigma=0.1, in_features=100, out_features=100),
    nn.ReLU(),
    bnn.BayesLinear(prior_mu=0, prior_sigma=0.1, in_features=100, out_features=6),
)

# %%
ce_loss = nn.CrossEntropyLoss()
kl_loss = bnn.BKLLoss(reduction='mean', last_layer_only=False)
kl_weight = 0.01
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %% [markdown]
#  Our model performs with 100% accuracy in multinomial classification as well.

# %%
for step in range(3000):
    pre = model(x)
    ce = ce_loss(pre,y)
    kl = kl_loss(model)
    cost = ce + kl_weight*kl
    
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()
    
_, predicted = torch.max(pre.data, 1)
total = y.size(0)
correct = (predicted == y).sum()
print('- Accuracy: %f %%' % (100 * float(correct) / total))
print('- CE : %2.2f, KL : %2.2f' % (ce.item(), kl.item()))
# Out:
# - Accuracy: 100.000000 %
# - CE : 0.00, KL : 0.59

# %%
def draw_plot(predicted) :
    fig = plt.figure(figsize = (16, 5))

    ax1 = fig.add_subplot(1, 2, 1)
    ax2 = fig.add_subplot(1, 2, 2)

    z1_plot = ax1.scatter(X[:, 0], X[:, 1], c = y)
    z2_plot = ax2.scatter(X[:, 0], X[:, 1], c = predicted)

    plt.colorbar(z1_plot,ax=ax1)
    plt.colorbar(z2_plot,ax=ax2)

    ax1.set_title("REAL")
    ax2.set_title("PREDICT")

    plt.show()

# %%
pre = model(x)
_, predicted = torch.max(pre.data, 1)
draw_plot(predicted)

# %% [markdown]
# # Conclusion:

# %% [markdown]
# As we see that bayesian neural network classifies such datasets which are impossible to be linearly classified with a standard methods. It also performs slightly better than the classical neural network.
